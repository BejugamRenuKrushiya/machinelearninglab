# %% [markdown]
# <a href="https://colab.research.google.com/github/BejugamRenuKrushiya/machinelearninglab/blob/main/Finds.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import csv


attributes = [['average', 'below average', 'not regular', 'regular'],
 ['absent', 'average', 'below average', 'excellent', 'good', 'very bad'],
 ['average', 'bad', 'below average', 'excellent', 'good'],
 ['FAIL', 'PASS']]


num_attributes = len(attributes)


print (" \n The most general hypothesis : ['?','?','?','?']\n")
print ("\n The most specific hypothesis : ['0','0','0','0']\n")

a = []
print("\n The Given Training Data Set \n")

with open('/content/Mid2 (1).csv', 'r') as csvFile:
    reader = csv.reader(csvFile)
    for row in reader:
        a.append (row)
        print(row)


print("\n The initial value of hypothesis: ")
hypothesis = ['0'] * num_attributes
print(hypothesis)

# Comparing with First Training Example 
for j in range(0,num_attributes):
        hypothesis[j] = a[0][j];

# Comparing with Remaining Training Examples of Given Data Set

print("\n Find S: Finding a Maximally Specific Hypothesis\n")

for i in range(0,len(a)):
    if a[i][num_attributes-1]=='PASS':
            for j in range(0,num_attributes):
                if a[i][j]!=hypothesis[j]:
                    hypothesis[j]='?'
                else :
                    hypothesis[j]= a[i][j] 
    print(" For Training Example No :{0} the hypothesis is ".format(i),hypothesis)
                
print("\n The Maximally Specific Hypothesis for a given Training Examples :\n")
print(hypothesis)
# Out:
#
#  The most general hypothesis : ['?','?','?','?']
#
#
#  The most specific hypothesis : ['0','0','0','0']
#
#
#  The Given Training Data Set
#
# ['not regular', 'very bad', 'bad', 'FAIL']
# ['regular', 'excellent', 'bad', 'FAIL']
# ['regular', 'excellent', 'average', 'PASS']
# ['regular', 'excellent', 'bad', 'FAIL']
# ['average', 'excellent', 'excellent', 'PASS']
# ['average', 'excellent', 'below average', 'PASS']
# ['average', 'excellent', 'excellent', 'PASS']
# ['regular', 'good', 'bad', 'FAIL']
# ['regular', 'excellent', 'excellent', 'PASS']
# ['below average', 'excellent', 'average', 'PASS']
# ['average', 'excellent', 'below average', 'PASS']
# ['not regular', 'below average', 'bad', 'FAIL']
# ['below average', 'excellent', 'good', 'PASS']
# ['regular', 'good', 'excellent', 'PASS']
# ['not regular', 'excellent', 'bad', 'FAIL']
# ['not regular', 'excellent', 'excellent', 'PASS']
# ['regular', 'below average', 'excellent', 'PASS']
# ['average', 'excellent', 'bad', 'FAIL']
# ...
